# %% [markdown]
# Este notebook tendra features asociados a ciertas palabras especificas

# %%
import pandas as pd
pd.set_option('max_colwidth', -1)
import string
import nltk
nltk.download('stopwords')
from nltk import word_tokenize
from nltk.corpus import stopwords
nltk.download('vader_lexicon')
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\brian\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\brian\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# Primero, carga del csv

# %%
df = pd.read_csv('../dataset/train.csv')
df_test = pd.read_csv('../dataset/test.csv')
df_test.drop(columns=['location', 'keyword'], inplace=True)
df = df.merge(df_test, how='outer')

# %%
df.head()
# Out:
#    id keyword location  \
# 0  1   NaN     NaN
# 1  4   NaN     NaN
# 2  5   NaN     NaN
# 3  6   NaN     NaN
# 4  7   NaN     NaN
#
#                                                                                                                                     text  \
# 0  Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1  Forest fire near La Ronge Sask. Canada
# 2  All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3  13,000 people receive #wildfires evacuation orders in California
# 4  Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
#
#    target
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %% [markdown]
# Por convencion con el resto del grupo, utilizamos id como indice. Como solo voy a trabajar con la columna text, elimino las otras dos

# %%
df.set_index('id',inplace = True)
df.drop(columns=['location', 'keyword', 'target'], inplace=True)

# %% [markdown]
# La primera idea que vamos a explorar, es evaluar si un tweet tiene mencion a una entidad divina o no. Para eso, vamos a preprocesar el campo text eliminando #, url, etc.

# %%
# Quitamos las urls
df['text'] = df['text'].str.replace(r'http:\/\/.*', '', regex=True).replace(r'https:\/\/.*', '', regex=True)

# Quitamos user mentions, signos de puntuación, hashtags y stopwords.
def clean_text(text):
    words = text.lower().split(' ')
    text = ' '.join([word for word in words if not word.startswith('@') and word not in stopwords.words('english')])
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

df['text'] = df['text'].apply(clean_text)

df['word_count'] = df['text'].apply(lambda x: len(x.split(' ')))

# %%
df.head()
# Out:
#                                                                                         text  \
# id
# 1   deeds reason earthquake may allah forgive us
# 4   forest fire near la ronge sask canada
# 5   residents asked shelter place notified officers evacuation shelter place orders expected
# 6   13000 people receive wildfires evacuation orders california
# 7   got sent photo ruby alaska smoke wildfires pours school
#
#     word_count
# id
# 1   7
# 4   7
# 5   11
# 6   8
# 7   10

# %% [markdown]
# Utilizaremos las principales religiones para esto: Cristianismo, Islam, Hinduismo, Budismo,Judaísmo.

# %%
dioses =[' god ',' allah ',' yahve ',' rog ',' shiva ',' visnu ',' ala ',' jesus ',' christ ',' jehova ',' zeus ',' poseidon ']

def chequear_mencion_divina(string):
    for dios in dioses:
        if dios in string:
            return True
    return False

df['mencion_divina'] = df['text'].apply(chequear_mencion_divina)

# %% [markdown]
# De manera similar, separamos en aquellos tweets que incluyan una risa.

# %%
def chequear_risa(string):
    if 'hah' in string:
        return True
    return False
df['contiene_risa'] = df['text'].apply(chequear_risa)

# %% [markdown]
# El uso de una hora especifica en un tweet, puede llegar a ser relevante. Se puede establecer, trabajando de forma similar,
# si existe una especificacion asi o no.

# %%
def chequear_hora(string):
    if ' pm ' in string or ' am ' in string: #Notar que necesito que existan los espacios a ambos lados
        return True
    return False
df['contiene_hora_especifica'] = df['text'].apply(chequear_hora)

# %% [markdown]
# Los Tweets que hacen mencion a la persona que los escribe, tienen tendencia a ser tweets no relacionados con algun desastre

# %%
pronombres =['i','m','me','us','im','am']
def chequear_pronombre(string):
    split = string.split(' ')
    for pronombre in pronombres:
        if pronombre in split:
            return True
    return False
df['mencion_personal'] = df['text'].apply(chequear_pronombre)

# %% [markdown]
# Utilizacion de infinitivos

# %%
def chequear_ing (string):
    if 'ing' in string:
        return True
    return False
df['Uso_infinitivos'] = df['text'].apply(chequear_ing)

# %% [markdown]
# Utilizacion de otros pronombres

# %%
pronombres = ['he','she','it','you']
df['mencion_tercero'] = df['text'].apply(chequear_pronombre)

# %%
df
# Out:
#                                                                                                                     text  \
# id
# 1      deeds reason earthquake may allah forgive us
# 4      forest fire near la ronge sask canada
# 5      residents asked shelter place notified officers evacuation shelter place orders expected
# 6      13000 people receive wildfires evacuation orders california
# 7      got sent photo ruby alaska smoke wildfires pours school
# 8      rockyfire update  california hwy 20 closed directions due lake county fire  cafire wildfires
# 10     flood disaster heavy rain causes flash flooding streets manitou colorado springs areas
# 13     im top hill see fire woods
# 14     theres emergency evacuation happening building across street
# 15     im afraid tornado coming area
# 16     three people died heat wave far
# 17     haha south tampa getting flooded hah wait second live south tampa gonna gonna fvck flooding
# 18     raining flooding florida tampabay tampa 18 19 days ive lost count
# 19     flood bago myanmar we arrived bago
# 20     damage school bus 80 multi car crash breaking
# 23     whats man
# 24     love fruits
# 25     summer lovely
# 26     car fast
# 28     goooooooaaaaaal
# 31     ridiculous
# 32     london cool
# 33     love skiing
# 34     wonderful day
# 36     looooool
# 37     wayi cant eat shit
# 38     nyc last week
# 39     love girlfriend
# 40     cooool
# 41     like pasta
# ...        ...
# 10756  wreckage conclusively confirmed mh370 malaysia pm investigators families were
# 10757  science piece wreckage flight mh370 confirmed rì©union island possible t
# 10758  wreckage conclusively confirmed mh370 malaysia pm
# 10761  wreckage conclusively confirmed mh370 malaysia pm investigators families were
# 10762  top story wreckage mh370 officially confirmed reports critical clue tiny island
# 10773  wreckage conclusively confirmed mh370 malaysia pm
# 10778  wreckage conclusively confirmed mh370 malaysia pm investigators families were
# 10781  rt debris found indian ocean island confirmed flight mh370
# 10791  cramer igers 3 words wrecked disneys stock
# 10792  almost wrecked van day guy yeah brake amp also care animals  get used it
# 10796  what manner human would parcel baby though wrecked car junk yard theû ûó dtom2
# 10797  thought said saturday night near died lolol wrecked
# 10801  wanna ease mind make feel alright
# 10804  think deactivated notifications aids tesco wrecked lol
# 10806  rt cnbc 3 words disney ceo bob iger wrecked disneys stock says jim cramer
# 10807  smackdown tyme put good mood since got wrecked smh
# 10816  jsyk stopped thinking abt remus slumped bathroom door day wrecked
# 10820  begovic garbage got wrecked red bull reserve team everyone else preseason
# 10828  wrecked today got hattrick
# 10836  ebola ebolaoutbreak ebola virus birmingham ala firefighters quarantined possible exposure officials say
# 10838  malaysian pm confirms debris missing flight mh370
# 10845  officials alabama home quarantined possible ebola case  washington times
# 10856  see 16yr old pkk suicide bomber detonated bomb turkey army trench released harun ìàekdar
# 10857  conference attendees blue line airport derailed  please look taking taxi hotel see soon
# 10858  death toll issuicide car bombing ypg position village rajman eastern province hasaka risen 9
# 10861  earthquake safety los angeles ûò safety fasteners xrwn
# 10865  storm ri worse last hurricane cityamp3others hardest hit yard looks like bombed around 20000k still without power
# 10868  green line derailment chicago
# 10874  meg issues hazardous weather outlook hwo
# 10875  cityofcalgary activated municipal emergency plan yycstorm
#
#        word_count  mencion_divina  contiene_risa  contiene_hora_especifica  \
# id
# 1      7           True            False          False
# 4      7           False           False          False
# 5      11          False           False          False
# 6      8           False           False          False
# 7      10          False           False          False
# 8      15          False           False          False
# 10     12          False           False          False
# 13     6           False           False          False
# 14     7           False           False          False
# 15     5           False           False          False
# 16     6           False           False          False
# 17     15          False           True           False
# 18     12          False           False          False
# 19     6           False           False          False
# 20     9           False           False          False
# 23     2           False           False          False
# 24     2           False           False          False
# 25     2           False           False          False
# 26     2           False           False          False
# 28     1           False           False          False
# 31     1           False           False          False
# 32     3           False           False          False
# 33     2           False           False          False
# 34     2           False           False          False
# 36     1           False           False          False
# 37     4           False           False          False
# 38     3           False           False          False
# 39     2           False           False          False
# 40     2           False           False          False
# 41     2           False           False          False
# ...   ..             ...             ...            ...
# 10756  10          False           False          True
# 10757  12          False           False          False
# 10758  6           False           False          False
# 10761  10          False           False          True
# 10762  12          False           False          False
# 10773  7           False           False          True
# 10778  10          False           False          True
# 10781  10          False           False          False
# 10791  8           False           False          False
# 10792  17          False           False          False
# 10796  15          False           False          False
# 10797  8           False           False          False
# 10801  6           False           False          False
# 10804  7           False           False          False
# 10806  15          False           False          False
# 10807  9           False           False          False
# 10816  11          False           False          False
# 10820  11          False           False          False
# 10828  5           False           False          False
# 10836  13          True            False          False
# 10838  8           False           False          True
# 10845  10          False           False          False
# 10856  16          False           False          False
# 10857  14          False           False          False
# 10858  14          False           False          False
# 10861  8           False           False          False
# 10865  17          False           False          False
# 10868  5           False           False          False
# 10874  7           False           False          False
# 10875  6           False           False          False
#
#        mencion_personal  Uso_infinitivos  mencion_tercero
# id
# 1      True              False            False
# 4      False             False            False
# 5      False             False            False
# 6      False             False            False
# 7      False             False            False
# 8      False             False            False
# 10     False             True             False
# 13     True              False            False
# 14     False             True             False
# 15     True              True             False
# 16     False             False            False
# 17     False             True             False
# 18     False             True             False
# 19     False             False            False
# 20     False             True             False
# 23     False             False            False
# 24     False             False            False
# 25     False             False            False
# 26     False             False            False
# 28     False             False            False
# 31     False             False            False
# 32     False             False            False
# 33     False             True             False
# 34     False             False            False
# 36     False             False            False
# 37     False             False            False
# 38     False             False            False
# 39     False             False            False
# 40     False             False            False
# 41     False             False            False
# ...      ...               ...              ...
# 10756  False             False            False
# 10757  False             False            False
# 10758  False             False            False
# 10761  False             False            False
# 10762  False             False            False
# 10773  False             False            False
# 10778  False             False            False
# 10781  False             False            False
# 10791  False             False            False
# 10792  False             False            True
# 10796  False             False            False
# 10797  False             False            False
# 10801  False             False            False
# 10804  False             False            False
# 10806  False             False            False
# 10807  False             False            False
# 10816  False             True             False
# 10820  False             False            False
# 10828  False             False            False
# 10836  False             True             False
# 10838  False             True             False
# 10845  False             True             False
# 10856  False             False            False
# 10857  False             True             False
# 10858  False             True             False
# 10861  False             False            False
# 10865  False             False            False
# 10868  False             False            False
# 10874  False             False            False
# 10875  False             False            False
#
# [10876 rows x 8 columns]

# %%
df.drop(columns=['text','word_count']).to_csv('../features/palabras_clave.csv', index=False)
