# %% [markdown]
# Este notebook tendra features asociados a ciertas palabras especificas

# %%
import pandas as pd
pd.set_option('max_colwidth', -1)
import string
import nltk
nltk.download('stopwords')
from nltk import word_tokenize
from nltk.corpus import stopwords
nltk.download('vader_lexicon')
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\brian\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\brian\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# Primero, carga del csv

# %%
df = pd.read_csv('../dataset/train.csv')

# %%
df.head()
# Out:
#    id keyword location  \
# 0  1   NaN     NaN
# 1  4   NaN     NaN
# 2  5   NaN     NaN
# 3  6   NaN     NaN
# 4  7   NaN     NaN
#
#                                                                                                                                     text  \
# 0  Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1  Forest fire near La Ronge Sask. Canada
# 2  All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3  13,000 people receive #wildfires evacuation orders in California
# 4  Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
#
#    target
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %% [markdown]
# Por convencion con el resto del grupo, utilizamos id como indice. Como solo voy a trabajar con la columna text, elimino las otras dos

# %%
df.set_index('id',inplace = True)
df.drop(columns=['location', 'keyword', 'target'], inplace=True)

# %% [markdown]
# La primera idea que vamos a explorar, es evaluar si un tweet tiene mencion a una entidad divina o no. Para eso, vamos a preprocesar el campo text eliminando #, url, etc.

# %%
# Quitamos las urls
df['text'] = df['text'].str.replace(r'http:\/\/.*', '', regex=True).replace(r'https:\/\/.*', '', regex=True)

# Quitamos user mentions, signos de puntuación, hashtags y stopwords.
def clean_text(text):
    words = text.lower().split(' ')
    text = ' '.join([word for word in words if not word.startswith('@') and word not in stopwords.words('english')])
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

df['text'] = df['text'].apply(clean_text)

df['word_count'] = df['text'].apply(lambda x: len(x.split(' ')))

# %%
df.head()
# Out:
#                                                                                         text  \
# id
# 1   deeds reason earthquake may allah forgive us
# 4   forest fire near la ronge sask canada
# 5   residents asked shelter place notified officers evacuation shelter place orders expected
# 6   13000 people receive wildfires evacuation orders california
# 7   got sent photo ruby alaska smoke wildfires pours school
#
#     word_count
# id
# 1   7
# 4   7
# 5   11
# 6   8
# 7   10

# %%
#Utilizaremos las principales religiones para esto: Cristianismo, Islam, Hinduismo, Budismo,Judaísmo.
dioses =[' god ',' allah ',' yahve ',' rog ',' shiva ',' visnu ',' ala ',' jesus ',' christ ',' jehova ']

def chequear_mencion_divina(string):
    for dios in dioses:
        if dios in string:
            return True
    return False

df['mencion_divina'] = df['text'].apply(chequear_mencion_divina)

# %%
#De manera similar, separamos en aquellos tweets que incluyan una risa.
def chequear_risa(string):
    if 'hah' in string:
        return True
    return False
df['contiene_risa'] = df['text'].apply(chequear_risa)

# %%
#El uso de una hora especifica en un tweet, puede llegar a ser relevante. Se puede establecer, trabajando de forma similar,
#si existe una especificacion asi o no.

def chequear_hora(string):
    if ' pm ' in string or ' am ' in string: #Notar que necesito que existan los espacios a ambos lados
        return True
    return False
df['contiene_hora_especifica'] = df['text'].apply(chequear_hora)

# %%
df
# Out:
#                                                                                                                          text  \
# id
# 1      deeds reason earthquake may allah forgive us
# 4      forest fire near la ronge sask canada
# 5      residents asked shelter place notified officers evacuation shelter place orders expected
# 6      13000 people receive wildfires evacuation orders california
# 7      got sent photo ruby alaska smoke wildfires pours school
# 8      rockyfire update  california hwy 20 closed directions due lake county fire  cafire wildfires
# 10     flood disaster heavy rain causes flash flooding streets manitou colorado springs areas
# 13     im top hill see fire woods
# 14     theres emergency evacuation happening building across street
# 15     im afraid tornado coming area
# 16     three people died heat wave far
# 17     haha south tampa getting flooded hah wait second live south tampa gonna gonna fvck flooding
# 18     raining flooding florida tampabay tampa 18 19 days ive lost count
# 19     flood bago myanmar we arrived bago
# 20     damage school bus 80 multi car crash breaking
# 23     whats man
# 24     love fruits
# 25     summer lovely
# 26     car fast
# 28     goooooooaaaaaal
# 31     ridiculous
# 32     london cool
# 33     love skiing
# 34     wonderful day
# 36     looooool
# 37     wayi cant eat shit
# 38     nyc last week
# 39     love girlfriend
# 40     cooool
# 41     like pasta
# ...        ...
# 10835  pic 16yr old pkk suicide bomber detonated bomb turkey army trench released
# 10837  boxes ready explode exploding kittens finally arrived gameofkittens explodingkittensû
# 10839  calgary police flood road closures calgary
# 10840  sismo detectado japìn 154107 seismic intensity 0 iwate miyagi jst
# 10841  sirens everywhere
# 10842  breaking isis claims responsibility mosque attack saudi arabia killed 13
# 10843  omg earthquake
# 10844  severe weather bulletin no 5 for typhoon ûïhannaphû soudelor tropical cyclone warning issued 500 pm 06
# 10846  heat wave warning aa ayyo dei plan visit friends year
# 10847  group suicide bomber detonated explosivespacked vest mosque inside saudi special forces headquarters killing 15 people
# 10848  heard really loud bang everyone asleep great
# 10849  gas thing exploded heard screams whole street smells gas
# 10850  nws flash flood warning continued shelby county 0800 pm wednesday
# 10851  rt nws issues severe thunderstorm warnings parts ar nc ok expect trauma cases
# 10852      mh370 aircraft debris found la reunion missing malaysia airlines
# 10853  fatherofthree lost control car overtaking collided bathandnortheastsomerset
# 10854  13 earthquake 9km ssw anza california iphone users download earthquake app information
# 10855  evacuation order lifted town roosevelt
# 10859  breaking la refugio oil spill may costlier bigger projected
# 10860  siren went forney tornado warning
# 10862  officials say quarantine place alabama home possible ebola case developing symptoms
# 10863  worldnews fallen powerlines glink tram update fire crews evacuated 30 passengers tr
# 10864  flip side im walmart bomb everyone evacuate stay tuned blow
# 10866  suicide bomber kills 15 saudi security site mosque  reuters via world  google news  wall
# 10867  stormchase violent record breaking ef5 el reno oklahoma tornado nearly runs
# 10869  two giant cranes holding bridge collapse nearby homes
# 10870  control wild fires california even northern part state troubling
# 10871  m194 0104 utc5km volcano hawaii
# 10872  police investigating ebike collided car little portugal ebike rider suffered serious nonlife threatening injuries
# 10873  latest homes razed northern california wildfire  abc news
#
#        word_count  mencion_divina  contiene_risa  contiene_hora_especifica
# id
# 1      7           True            False          False
# 4      7           False           False          False
# 5      11          False           False          False
# 6      8           False           False          False
# 7      10          False           False          False
# 8      15          False           False          False
# 10     12          False           False          False
# 13     6           False           False          False
# 14     7           False           False          False
# 15     5           False           False          False
# 16     6           False           False          False
# 17     15          False           True           False
# 18     12          False           False          False
# 19     6           False           False          False
# 20     9           False           False          False
# 23     2           False           False          False
# 24     2           False           False          False
# 25     2           False           False          False
# 26     2           False           False          False
# 28     1           False           False          False
# 31     1           False           False          False
# 32     3           False           False          False
# 33     2           False           False          False
# 34     2           False           False          False
# 36     1           False           False          False
# 37     4           False           False          False
# 38     3           False           False          False
# 39     2           False           False          False
# 40     2           False           False          False
# 41     2           False           False          False
# ...   ..             ...             ...            ...
# 10835  13          False           False          False
# 10837  10          False           False          False
# 10839  7           False           False          False
# 10840  12          False           False          False
# 10841  2           False           False          False
# 10842  11          False           False          False
# 10843  2           False           False          False
# 10844  17          False           False          True
# 10846  10          False           False          False
# 10847  15          False           False          False
# 10848  7           False           False          False
# 10849  11          False           False          False
# 10850  11          False           False          True
# 10851  14          False           False          False
# 10852  15          False           False          False
# 10853  8           False           False          False
# 10854  13          False           False          False
# 10855  6           False           False          False
# 10859  10          False           False          False
# 10860  6           False           False          False
# 10862  12          False           False          False
# 10863  13          False           False          False
# 10864  10          False           False          False
# 10866  19          False           False          False
# 10867  14          False           False          False
# 10869  9           False           False          False
# 10870  9           False           False          False
# 10871  6           False           False          False
# 10872  14          False           False          False
# 10873  10          False           False          False
#
# [7613 rows x 5 columns]

# %%
df.drop(columns=['text']).to_csv('../features/palabras_clave.csv', index=False)
